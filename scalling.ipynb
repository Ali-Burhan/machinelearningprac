# %%
import pandas as pd

# %%
dataset = pd.read_csv('./dataset.csv')

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    Male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    Male  35.0      0      0   8.0500
#
#    Embarked
# 0         3
# 1         1
# 2         3
# 3         3
# 4         3

# %%
fare_col = dataset['Fare']

# %%
fare_col
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 884    13.0000
# 885    30.0000
# 886    23.4500
# 887    30.0000
# 888     7.7500
# Name: Fare, Length: 889, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sclaer = StandardScaler()

# %%
result = sclaer.fit_transform(fare_col.values.reshape(-1,1))

# %%
result
# Out:
# array([[-5.00239751e-01],
#        [ 7.88946608e-01],
#        [-4.86649935e-01],
#        [ 4.22861113e-01],
#        [-4.84133302e-01],
#        [-4.75912973e-01],
#        [ 3.97946450e-01],
#        [-2.21900178e-01],
#        [-4.22057034e-01],
#        [-4.07871840e-02],
#        [-3.09982321e-01],
#        [-1.11671667e-01],
#        [-4.84133302e-01],
#        [-1.65429515e-02],
#        [-4.88075355e-01],
#        [-3.24075464e-01],
#        [-5.98290335e-02],
#        [-3.84474648e-01],
#        [-2.83809341e-01],
#        [-5.00743078e-01],
#        [-1.22744850e-01],
#        [-3.84474648e-01],
#        [-4.84552070e-01],
#        [ 6.85192328e-02],
#        [-2.21900178e-01],
#        [-1.42779821e-02],
#        [-5.00743078e-01],
#        [ 4.64879070e+00],
#        [-4.87572029e-01],
#        [-4.87237820e-01],
#        [-8.80998783e-02],
#        [ 2.30370781e+00],
#        [-4.90173220e-01],
#        [-4.34807302e-01],
#        [ 1.00814531e+00],
# ...
