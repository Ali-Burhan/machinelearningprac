# %%
import pandas as pd
dataset = pd.read_csv('./dataset.csv')

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
fare = dataset['Fare'].values.reshape(-1,1)

# %%
minmax = MinMaxScaler()

# %%
result = minmax.fit_transform(fare)

# %%
result
# Out:
# array([[0.01415106],
#        [0.13913574],
#        [0.01546857],
#        [0.1036443 ],
#        [0.01571255],
#        [0.0165095 ],
#        [0.10122886],
#        [0.04113566],
#        [0.02173075],
#        [0.05869429],
#        [0.03259623],
#        [0.05182215],
#        [0.01571255],
#        [0.06104473],
#        [0.01533038],
#        [0.03122992],
#        [0.05684821],
#        [0.02537431],
#        [0.03513366],
#        [0.01410226],
#        [0.05074862],
#        [0.02537431],
#        [0.01567195],
#        [0.06929139],
#        [0.04113566],
#        [0.06126432],
#        [0.01410226],
#        [0.51334181],
#        [0.01537917],
#        [0.01541158],
#        [0.0541074 ],
#        [0.28598956],
#        [0.01512699],
#        [0.02049464],
#        [0.16038672],
#        [0.10149724],
#        [0.01411046],
#        [0.01571255],
#        [0.03513366],
#        [0.02194234],
#        [0.01849397],
#        [0.04098927],
#        [0.01541158],
# ...
